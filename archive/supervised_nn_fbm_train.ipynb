# %%
#Python script to train, evaluate and save model to estimate the Hurst exponent from trajectory of fBm.

# import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from stochastic.processes.continuous import FractionalBrownianMotion

#generate our data for training and testing
nsamples = 10000

ntimes = 20  # THIS IS SIZE OF WINDOW

traindata = np.empty((nsamples,ntimes))
trainlabels = np.empty((nsamples,1))
for i in range(0,nsamples):
    hurst_exp = np.random.uniform(0.,1.)
    fbm = FractionalBrownianMotion(hurst=hurst_exp,t=1,rng=None)
    x = fbm.sample(ntimes)
    #apply differencing and normalization on the data
    dx = (x[1:]-x[0:-1])/(np.amax(x)-np.amin(x))
    traindata[i,:] = dx
    trainlabels[i,:] = hurst_exp
testdata = np.empty((nsamples,ntimes))
testlabels = np.empty((nsamples,1))
for i in range(0,nsamples):
    hurst_exp = np.random.uniform(0.,1.)
    fbm = FractionalBrownianMotion(hurst=hurst_exp,t=1,rng=None)
    x = fbm.sample(ntimes)
    dx = (x[1:]-x[0:-1])/(np.amax(x)-np.amin(x))
    testdata[i,:] = dx
    testlabels[i,:] = hurst_exp
np.savetxt("H_testvalues_n"+str(ntimes)+".csv",testlabels,delimiter=",")

print('training data shape:',traindata.shape,'training labels shape:', trainlabels.shape,'test data shape:',testdata.shape,'test labels shape:',testlabels.shape)

#create the model for a fully-connected network
model = tf.keras.Sequential([
    tf.keras.layers.Dense(ntimes,activation='relu',input_shape=(ntimes,)),
    tf.keras.layers.Dense(ntimes-1,activation='relu'),
    tf.keras.layers.Dense(ntimes-2,activation='relu'),
    tf.keras.layers.Dense(1,activation='relu')
])
#add optimizer, a loss function and metrics#
optimizer = 'adam'
# optimizer = tf.keras.optimizers.RMSprop(0.001)
model.compile(optimizer=optimizer,
              loss='mean_absolute_error',
              metrics=['mean_absolute_error','mean_squared_error']
)
model.summary()
#train the model
EPOCHS = 100
history = model.fit(traindata,trainlabels,epochs=EPOCHS,validation_split=0.6,verbose=1)

#Save model
print("Saving model")
model.save("./model3dense_n"+str(ntimes)+".h5")
del model
model = tf.keras.models.load_model("./model3dense_n"+str(ntimes)+".h5")

#evaluate the model generalizes by using the test data set
loss, mae, mse = model.evaluate(testdata, testlabels, verbose=1)
print("Testing set Mean Abs Error: {:5.2f}".format(mae))
#predict values using data in the testing set
test_predictions = model.predict(testdata)
#save predicted values
np.savetxt("H_NNestimated_n"+str(ntimes)+".csv",test_predictions,delimiter=",")
# Out:
# training data shape: (10000, 10) training labels shape: (10000, 1) test data shape: (10000, 10) test labels shape: (10000, 1)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                110
#
#  dense_1 (Dense)             (None, 9)                 99
#
#  dense_2 (Dense)             (None, 8)                 80
#
#  dense_3 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 298
# Trainable params: 298
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.3259 - mean_absolute_error: 0.3259 - mean_squared_error: 0.1567 - val_loss: 0.2416 - val_mean_absolute_error: 0.2416 - val_mean_squared_error: 0.0800
# Epoch 2/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2083 - mean_absolute_error: 0.2083 - mean_squared_error: 0.0623 - val_loss: 0.1865 - val_mean_absolute_error: 0.1865 - val_mean_squared_error: 0.0528
# Epoch 3/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1746 - mean_absolute_error: 0.1746 - mean_squared_error: 0.0477 - val_loss: 0.1686 - val_mean_absolute_error: 0.1686 - val_mean_squared_error: 0.0448
# Epoch 4/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1606 - mean_absolute_error: 0.1606 - mean_squared_error: 0.0423 - val_loss: 0.1601 - val_mean_absolute_error: 0.1601 - val_mean_squared_error: 0.0412
# Epoch 5/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1548 - mean_absolute_error: 0.1548 - mean_squared_error: 0.0396 - val_loss: 0.1557 - val_mean_absolute_error: 0.1557 - val_mean_squared_error: 0.0395
# Epoch 6/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1510 - mean_absolute_error: 0.1510 - mean_squared_error: 0.0378 - val_loss: 0.1534 - val_mean_absolute_error: 0.1534 - val_mean_squared_error: 0.0387
# Epoch 7/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1493 - mean_absolute_error: 0.1493 - mean_squared_error: 0.0373 - val_loss: 0.1519 - val_mean_absolute_error: 0.1519 - val_mean_squared_error: 0.0376
# Epoch 8/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1476 - mean_absolute_error: 0.1476 - mean_squared_error: 0.0360 - val_loss: 0.1504 - val_mean_absolute_error: 0.1504 - val_mean_squared_error: 0.0371
# Epoch 9/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1459 - mean_absolute_error: 0.1459 - mean_squared_error: 0.0355 - val_loss: 0.1492 - val_mean_absolute_error: 0.1492 - val_mean_squared_error: 0.0369
# Epoch 10/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1449 - mean_absolute_error: 0.1449 - mean_squared_error: 0.0350 - val_loss: 0.1484 - val_mean_absolute_error: 0.1484 - val_mean_squared_error: 0.0366
# Epoch 11/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1442 - mean_absolute_error: 0.1442 - mean_squared_error: 0.0347 - val_loss: 0.1480 - val_mean_absolute_error: 0.1480 - val_mean_squared_error: 0.0366
# Epoch 12/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1436 - mean_absolute_error: 0.1436 - mean_squared_error: 0.0346 - val_loss: 0.1473 - val_mean_absolute_error: 0.1473 - val_mean_squared_error: 0.0362
# Epoch 13/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1428 - mean_absolute_error: 0.1428 - mean_squared_error: 0.0340 - val_loss: 0.1472 - val_mean_absolute_error: 0.1472 - val_mean_squared_error: 0.0362
# Epoch 14/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1421 - mean_absolute_error: 0.1421 - mean_squared_error: 0.0340 - val_loss: 0.1476 - val_mean_absolute_error: 0.1476 - val_mean_squared_error: 0.0356
# Epoch 15/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1420 - mean_absolute_error: 0.1420 - mean_squared_error: 0.0337 - val_loss: 0.1463 - val_mean_absolute_error: 0.1463 - val_mean_squared_error: 0.0355
# Epoch 16/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1417 - mean_absolute_error: 0.1417 - mean_squared_error: 0.0337 - val_loss: 0.1469 - val_mean_absolute_error: 0.1469 - val_mean_squared_error: 0.0356
# Epoch 17/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1414 - mean_absolute_error: 0.1414 - mean_squared_error: 0.0334 - val_loss: 0.1471 - val_mean_absolute_error: 0.1471 - val_mean_squared_error: 0.0357
# Epoch 18/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1407 - mean_absolute_error: 0.1407 - mean_squared_error: 0.0332 - val_loss: 0.1458 - val_mean_absolute_error: 0.1458 - val_mean_squared_error: 0.0355
# Epoch 19/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1412 - mean_absolute_error: 0.1412 - mean_squared_error: 0.0335 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0353
# Epoch 20/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1404 - mean_absolute_error: 0.1404 - mean_squared_error: 0.0332 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0352
# Epoch 21/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1402 - mean_absolute_error: 0.1402 - mean_squared_error: 0.0330 - val_loss: 0.1474 - val_mean_absolute_error: 0.1474 - val_mean_squared_error: 0.0363
# Epoch 22/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1401 - mean_absolute_error: 0.1401 - mean_squared_error: 0.0331 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457 - val_mean_squared_error: 0.0358
# Epoch 23/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1400 - mean_absolute_error: 0.1400 - mean_squared_error: 0.0330 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0349
# Epoch 24/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1395 - mean_absolute_error: 0.1395 - mean_squared_error: 0.0328 - val_loss: 0.1469 - val_mean_absolute_error: 0.1469 - val_mean_squared_error: 0.0356
# Epoch 25/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1391 - mean_absolute_error: 0.1391 - mean_squared_error: 0.0327 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0348
# Epoch 26/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0326 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448 - val_mean_squared_error: 0.0351
# Epoch 27/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1390 - mean_absolute_error: 0.1390 - mean_squared_error: 0.0328 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0349
# Epoch 28/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1387 - mean_absolute_error: 0.1387 - mean_squared_error: 0.0327 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451 - val_mean_squared_error: 0.0351
# Epoch 29/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1386 - mean_absolute_error: 0.1386 - mean_squared_error: 0.0325 - val_loss: 0.1472 - val_mean_absolute_error: 0.1472 - val_mean_squared_error: 0.0365
# Epoch 30/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1385 - mean_absolute_error: 0.1385 - mean_squared_error: 0.0326 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448 - val_mean_squared_error: 0.0349
# Epoch 31/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1385 - mean_absolute_error: 0.1385 - mean_squared_error: 0.0325 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0358
# Epoch 32/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1382 - mean_absolute_error: 0.1382 - mean_squared_error: 0.0325 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459 - val_mean_squared_error: 0.0350
# Epoch 33/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1381 - mean_absolute_error: 0.1381 - mean_squared_error: 0.0323 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451 - val_mean_squared_error: 0.0350
# Epoch 34/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1382 - mean_absolute_error: 0.1382 - mean_squared_error: 0.0324 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0351
# Epoch 35/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1381 - mean_absolute_error: 0.1381 - mean_squared_error: 0.0324 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0350
# Epoch 36/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1376 - mean_absolute_error: 0.1376 - mean_squared_error: 0.0322 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0350
# Epoch 37/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1378 - mean_absolute_error: 0.1378 - mean_squared_error: 0.0322 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0358
# Epoch 38/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1374 - mean_absolute_error: 0.1374 - mean_squared_error: 0.0322 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447 - val_mean_squared_error: 0.0354
# Epoch 39/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0321 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0350
# Epoch 40/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0322 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447 - val_mean_squared_error: 0.0348
# Epoch 41/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0322 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448 - val_mean_squared_error: 0.0351
# Epoch 42/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0321 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0351
# Epoch 43/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0321 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0356
# Epoch 44/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1373 - mean_absolute_error: 0.1373 - mean_squared_error: 0.0323 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0352
# Epoch 45/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0322 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0353
# Epoch 46/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1372 - mean_absolute_error: 0.1372 - mean_squared_error: 0.0323 - val_loss: 0.1447 - val_mean_absolute_error: 0.1447 - val_mean_squared_error: 0.0350
# Epoch 47/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1370 - mean_absolute_error: 0.1370 - mean_squared_error: 0.0322 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451 - val_mean_squared_error: 0.0354
# Epoch 48/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1368 - mean_absolute_error: 0.1368 - mean_squared_error: 0.0321 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459 - val_mean_squared_error: 0.0355
# Epoch 49/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0320 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0352
# Epoch 50/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0319 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0353
# Epoch 51/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1364 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0320 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0360
# Epoch 52/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1365 - mean_absolute_error: 0.1365 - mean_squared_error: 0.0320 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448 - val_mean_squared_error: 0.0354
# Epoch 53/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1361 - mean_absolute_error: 0.1361 - mean_squared_error: 0.0318 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451 - val_mean_squared_error: 0.0353
# Epoch 54/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1362 - mean_absolute_error: 0.1362 - mean_squared_error: 0.0321 - val_loss: 0.1451 - val_mean_absolute_error: 0.1451 - val_mean_squared_error: 0.0351
# Epoch 55/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1360 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0319 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0350
# Epoch 56/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1360 - mean_absolute_error: 0.1360 - mean_squared_error: 0.0319 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0353
# Epoch 57/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1358 - mean_absolute_error: 0.1358 - mean_squared_error: 0.0318 - val_loss: 0.1458 - val_mean_absolute_error: 0.1458 - val_mean_squared_error: 0.0353
# Epoch 58/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1364 - mean_absolute_error: 0.1364 - mean_squared_error: 0.0322 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0352
# Epoch 59/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1359 - mean_absolute_error: 0.1359 - mean_squared_error: 0.0318 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0355
# Epoch 60/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - mean_squared_error: 0.0317 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459 - val_mean_squared_error: 0.0361
# Epoch 61/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0320 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0350
# Epoch 62/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - mean_squared_error: 0.0318 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0352
# Epoch 63/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - mean_squared_error: 0.0316 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0352
# Epoch 64/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0317 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0354
# Epoch 65/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - mean_squared_error: 0.0317 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0353
# Epoch 66/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0316 - val_loss: 0.1468 - val_mean_absolute_error: 0.1468 - val_mean_squared_error: 0.0355
# Epoch 67/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1356 - mean_absolute_error: 0.1356 - mean_squared_error: 0.0317 - val_loss: 0.1473 - val_mean_absolute_error: 0.1473 - val_mean_squared_error: 0.0357
# Epoch 68/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1355 - mean_absolute_error: 0.1355 - mean_squared_error: 0.0318 - val_loss: 0.1461 - val_mean_absolute_error: 0.1461 - val_mean_squared_error: 0.0354
# Epoch 69/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1353 - mean_absolute_error: 0.1353 - mean_squared_error: 0.0317 - val_loss: 0.1462 - val_mean_absolute_error: 0.1462 - val_mean_squared_error: 0.0357
# Epoch 70/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0316 - val_loss: 0.1458 - val_mean_absolute_error: 0.1458 - val_mean_squared_error: 0.0352
# Epoch 71/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1351 - mean_absolute_error: 0.1351 - mean_squared_error: 0.0316 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0354
# Epoch 72/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1352 - mean_absolute_error: 0.1352 - mean_squared_error: 0.0316 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0350
# Epoch 73/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1347 - mean_absolute_error: 0.1347 - mean_squared_error: 0.0314 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0354
# Epoch 74/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0315 - val_loss: 0.1462 - val_mean_absolute_error: 0.1462 - val_mean_squared_error: 0.0356
# Epoch 75/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1357 - mean_absolute_error: 0.1357 - mean_squared_error: 0.0318 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457 - val_mean_squared_error: 0.0352
# Epoch 76/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1350 - mean_absolute_error: 0.1350 - mean_squared_error: 0.0315 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0351
# Epoch 77/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0313 - val_loss: 0.1448 - val_mean_absolute_error: 0.1448 - val_mean_squared_error: 0.0353
# Epoch 78/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0315 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0353
# Epoch 79/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0314 - val_loss: 0.1449 - val_mean_absolute_error: 0.1449 - val_mean_squared_error: 0.0354
# Epoch 80/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1348 - mean_absolute_error: 0.1348 - mean_squared_error: 0.0315 - val_loss: 0.1457 - val_mean_absolute_error: 0.1457 - val_mean_squared_error: 0.0354
# Epoch 81/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1345 - mean_absolute_error: 0.1345 - mean_squared_error: 0.0314 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0358
# Epoch 82/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0315 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0356
# Epoch 83/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1341 - mean_absolute_error: 0.1341 - mean_squared_error: 0.0313 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0356
# Epoch 84/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0313 - val_loss: 0.1450 - val_mean_absolute_error: 0.1450 - val_mean_squared_error: 0.0353
# Epoch 85/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0315 - val_loss: 0.1463 - val_mean_absolute_error: 0.1463 - val_mean_squared_error: 0.0354
# Epoch 86/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0313 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0354
# Epoch 87/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1343 - mean_absolute_error: 0.1343 - mean_squared_error: 0.0314 - val_loss: 0.1452 - val_mean_absolute_error: 0.1452 - val_mean_squared_error: 0.0353
# Epoch 88/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1341 - mean_absolute_error: 0.1341 - mean_squared_error: 0.0313 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0354
# Epoch 89/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0314 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459 - val_mean_squared_error: 0.0352
# Epoch 90/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0313 - val_loss: 0.1453 - val_mean_absolute_error: 0.1453 - val_mean_squared_error: 0.0355
# Epoch 91/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1342 - mean_absolute_error: 0.1342 - mean_squared_error: 0.0313 - val_loss: 0.1464 - val_mean_absolute_error: 0.1464 - val_mean_squared_error: 0.0358
# Epoch 92/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - mean_squared_error: 0.0313 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0357
# Epoch 93/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - mean_squared_error: 0.0313 - val_loss: 0.1475 - val_mean_absolute_error: 0.1475 - val_mean_squared_error: 0.0359
# Epoch 94/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1338 - mean_absolute_error: 0.1338 - mean_squared_error: 0.0313 - val_loss: 0.1464 - val_mean_absolute_error: 0.1464 - val_mean_squared_error: 0.0354
# Epoch 95/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1339 - mean_absolute_error: 0.1339 - mean_squared_error: 0.0313 - val_loss: 0.1463 - val_mean_absolute_error: 0.1463 - val_mean_squared_error: 0.0359
# Epoch 96/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1338 - mean_absolute_error: 0.1338 - mean_squared_error: 0.0312 - val_loss: 0.1454 - val_mean_absolute_error: 0.1454 - val_mean_squared_error: 0.0356
# Epoch 97/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1340 - mean_absolute_error: 0.1340 - mean_squared_error: 0.0313 - val_loss: 0.1456 - val_mean_absolute_error: 0.1456 - val_mean_squared_error: 0.0359
# Epoch 98/100
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1335 - mean_absolute_error: 0.1335 - mean_squared_error: 0.0312 - val_loss: 0.1459 - val_mean_absolute_error: 0.1459 - val_mean_squared_error: 0.0353
# Epoch 99/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1344 - mean_absolute_error: 0.1344 - mean_squared_error: 0.0314 - val_loss: 0.1469 - val_mean_absolute_error: 0.1469 - val_mean_squared_error: 0.0358
# Epoch 100/100
# 125/125 [==============================] - 0s 4ms/step - loss: 0.1337 - mean_absolute_error: 0.1337 - mean_squared_error: 0.0313 - val_loss: 0.1455 - val_mean_absolute_error: 0.1455 - val_mean_squared_error: 0.0352
# Saving model
# 313/313 [==============================] - 1s 1ms/step - loss: 0.1451 - mean_absolute_error: 0.1451 - mean_squared_error: 0.0346
# Testing set Mean Abs Error:  0.15
# 313/313 [==============================] - 0s 1ms/step
